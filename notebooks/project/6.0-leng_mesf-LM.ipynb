# %% [markdown]
# # Auto reload modules

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
import fs

# %%
PROCESSED_DIR = fs.open_fs("../../data/processed/project")
CARS_PROCESSED_CSV_DIR = PROCESSED_DIR.getsyspath("car_dataframe_processed.csv")

# %%
df = pd.read_csv(CARS_PROCESSED_CSV_DIR)

# %%
df.columns
# Out:
# Index(['horsepower3', 'displacement', 'gears', 'torque_log', 'age',
#        'fuel_consumption_km_l'],
#       dtype='object')

# %%
df
# Out:
#       horsepower3  displacement  gears  torque_log  age  fuel_consumption_km_l
# 0        90518849           3.0    7.0    6.246107    9                    7.0
# 1        29791000           3.0    8.0    5.783825    7                   10.0
# 2        27000000           2.0    8.0    5.686975    6                   11.0
# 3         3375000           1.4    7.0    4.997212    6                   17.0
# 4        32768000           2.0    8.0    5.686975    7                   12.0
# ...           ...           ...    ...         ...  ...                    ...
# 1230      2744000           1.8    5.0    4.859812   10                   16.0
# 1231      1225043           1.6    5.0    4.644391    3                   17.0
# 1232      1000000           1.6    5.0    4.653960    6                   17.0
# 1233      1000000           1.6    5.0    4.653960    9                   14.0
# 1234      1157625           1.6    5.0    4.672829    7                   14.0
#
# [1235 rows x 6 columns]

# %%
X_cols = ['horsepower3', 'displacement', 'gears', 'torque_log', 'age']
y_cols = 'fuel_consumption_km_l'

# %%
X_df = df[X_cols]
y_df = df[y_cols]

# %%
# Estandarización
scaler = StandardScaler()
X_scaled_df = scaler.fit_transform(X_df)
# Out:
# c:\Users\Anony\anaconda3\envs\mcd_econometrics\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\Anony\anaconda3\envs\mcd_econometrics\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\Anony\anaconda3\envs\mcd_econometrics\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
df_scaled = pd.DataFrame(X_scaled_df)
df_scaled.columns = X_cols

# %%
df_scaled[y_cols] = df[y_cols]

# %%
df_scaled
# Out:
#       horsepower3  displacement     gears  torque_log       age  \
# 0        5.168934      0.926112  0.663204    2.657791  0.630228
# 1        1.265834      0.926112  1.507592    1.538746 -0.237961
# 2        1.086451     -0.164522  1.507592    1.304302 -0.672055
# 3       -0.431974     -0.818903  0.663204   -0.365407 -0.672055
# 4        1.457172     -0.164522  1.507592    1.304302 -0.237961
# ...           ...           ...       ...         ...       ...
# 1230    -0.472530     -0.382649 -1.025573   -0.698011  1.064322
# 1231    -0.570156     -0.600776 -1.025573   -1.219482 -1.974338
# 1232    -0.584620     -0.600776 -1.025573   -1.196317 -0.672055
# 1233    -0.584620     -0.600776 -1.025573   -1.196317  0.630228
# 1234    -0.574490     -0.600776 -1.025573   -1.150642 -0.237961
#
#       fuel_consumption_km_l
# 0                       7.0
# 1                      10.0
# 2                      11.0
# 3                      17.0
# 4                      12.0
# ...

# %%
model = (
    smf.ols(
        formula='fuel_consumption_km_l ~ horsepower3 + displacement + gears + torque_log + age',
        data=df
    )
    .fit()
)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     fuel_consumption_km_l   R-squared:                       0.608
# Model:                               OLS   Adj. R-squared:                  0.606
# Method:                    Least Squares   F-statistic:                     380.8
# Date:                   Thu, 03 Oct 2024   Prob (F-statistic):          9.53e-247
# Time:                           19:56:25   Log-Likelihood:                -2696.4
# No. Observations:                   1235   AIC:                             5405.
# Df Residuals:                       1229   BIC:                             5436.
# Df Model:                              5
# Covariance Type:               nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
model_2 = (
    smf.ols(
        formula='fuel_consumption_km_l ~ displacement + gears + torque_log + age',
        data=df
    )
    .fit()
)
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     fuel_consumption_km_l   R-squared:                       0.601
# Model:                               OLS   Adj. R-squared:                  0.599
# Method:                    Least Squares   F-statistic:                     462.2
# Date:                   Thu, 03 Oct 2024   Prob (F-statistic):          3.12e-243
# Time:                           19:59:47   Log-Likelihood:                -2707.7
# No. Observations:                   1235   AIC:                             5425.
# Df Residuals:                       1230   BIC:                             5451.
# Df Model:                              4
# Covariance Type:               nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
model_3 = (
    smf.ols(
        formula='fuel_consumption_km_l ~ displacement + torque_log + age',
        data=df
    )
    .fit()
)
model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     fuel_consumption_km_l   R-squared:                       0.600
# Model:                               OLS   Adj. R-squared:                  0.599
# Method:                    Least Squares   F-statistic:                     616.1
# Date:                   Thu, 03 Oct 2024   Prob (F-statistic):          1.73e-244
# Time:                           20:00:09   Log-Likelihood:                -2708.1
# No. Observations:                   1235   AIC:                             5424.
# Df Residuals:                       1231   BIC:                             5445.
# Df Model:                              3
# Covariance Type:               nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
